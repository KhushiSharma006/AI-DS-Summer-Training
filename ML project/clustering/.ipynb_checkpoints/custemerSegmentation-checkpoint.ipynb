# %%
import pandas as pd
from sklearn.cluster import KMeans


df = pd.read_csv("customer_segmentation_100_records.csv")


print(df)

x = df[["Age", "Annual_Income", "Spending_Score"]]


model = KMeans(n_clusters=3, random_state=42)


df["Cluster"] = model.fit_predict(x)

print(df)


print("Cluster Centers:")
print(model.cluster_centers_)
# Out:
#    Customer_ID  Age  Gender  Annual_Income  Spending_Score  Purchase_Frequency
# 0         C001   21  Female          21700              94                  14
# 1         C002   22    Male          23400              93                  13
# 2         C003   23  Female          25100              92                  12
# 3         C004   24    Male          26800              91                  11
# 4         C005   25  Female          28500              90                  10
# ..         ...  ...     ...            ...             ...                 ...
# 95        C096   46    Male         183200              49                   9
# 96        C097   47  Female         184900              48                   8
# 97        C098   48    Male         186600              47                   7
# 98        C099   49  Female         188300              46                   6
# 99        C100   50    Male         190000              95                   5
#
# [100 rows x 6 columns]
#    Customer_ID  Age  Gender  Annual_Income  Spending_Score  \
# 0         C001   21  Female          21700              94
# 1         C002   22    Male          23400              93
# 2         C003   23  Female          25100              92
# 3         C004   24    Male          26800              91
# 4         C005   25  Female          28500              90
# ..         ...  ...     ...            ...             ...
# 95        C096   46    Male         183200              49
# 96        C097   47  Female         184900              48
# 97        C098   48    Male         186600              47
# 98        C099   49  Female         188300              46
# 99        C100   50    Male         190000              95
#
#     Purchase_Frequency  Cluster
# 0                   14        2
# 1                   13        2
# 2                   12        2
# 3                   11        2
# 4                   10        2
# ..                 ...      ...
# 95                   9        1
# 96                   8        1
# 97                   7        1
# 98                   6        1
# 99                   5        1
#
# [100 rows x 7 columns]
# Cluster Centers:
# [[3.65588235e+01 1.04150000e+05 7.05000000e+01]
#  [3.65882353e+01 1.61950000e+05 6.29705882e+01]
#  [3.65000000e+01 4.80500000e+04 7.85000000e+01]]
# C:\Users\khushi\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
