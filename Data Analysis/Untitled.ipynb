# %%
 Question 1: Car Sales Analysis Dashboard
Problem Statement
A car showroom wants to analyze the sales performance of different car brands.
Dataset
import pandas as pd

data = {
    "Brand": ["Toyota", "Honda", "Hyundai", "Tata", "Mahindra", "Kia"],
    "Sales": [120, 95, 110, 85, 100, 90],
    "Price": [12, 10, 11, 9, 14, 13],
    "Mileage": [18, 20, 19, 22, 17, 18]
}

df = pd.DataFrame(data)
________________________________________
Create a 2 × 2 Dashboard
Graph 1 (Position 1)
Create a Bar Plot showing Brand vs Sales.
•	Palette = "Set2" 
•	Title = "Car Sales" 
________________________________________
Graph 2 (Position 2)
Create a Scatter Plot showing Price vs Sales.
•	Marker Size = 150 
•	Color = Green 
•	Title = "Price vs Sales" 
________________________________________
Graph 3 (Position 3)
Create a Histogram of Mileage.
•	Bins = 6 
•	Color = Orange 
•	Title = "Mileage Distribution" 
________________________________________
Graph 4 (Position 4)
Create a Box Plot for Sales.
•	Color = Sky Blue 
•	Title = "Sales Outlier Detection"
Expected Dashboard
•---------------------------------------
| Car Sales | Price vs Sales          |
---------------------------------------
| Histogram | Box Plot                |
---------------------------------------


Question 2: Hospital Patient Analysis Dashboard
Problem Statement
A hospital wants to analyze patient information using different graphs.
Dataset
import pandas as pd

data = {
    "Patient": ["P1","P2","P3","P4","P5","P6","P7","P8"],
    "Age": [25,40,35,60,45,30,55,50],
    "BloodPressure": [120,140,130,160,150,125,155,145],
    "Sugar": [90,110,105,180,150,95,170,140]
}

df = pd.DataFrame(data)
________________________________________
Create a 2 × 2 Dashboard
Graph 1
Create a Line Plot
•	X-axis → Patient 
•	Y-axis → BloodPressure 
•	Marker = "o" 
•	Color = Blue 
•	Title = "Blood Pressure" 
________________________________________
Graph 2
Create a Scatter Plot
•	X-axis → Age 
•	Y-axis → Sugar 
•	Color = Red 
•	Marker Size = 120 
•	Title = "Age vs Sugar" 
________________________________________
Graph 3
Create a Histogram
•	Plot BloodPressure 
•	Bins = 5 
•	Color = Purple 
•	Title = "Blood Pressure Distribution" 
________________________________________
Graph 4
Create a Box Plot
•	Plot Sugar 
•	Color = Light Green 
•	Title = "Sugar Outliers" 
________________________________________
Finally
plt.tight_layout()
plt.show()
________________________________________
Expected Dashboard
------------------------------------------------
| Blood Pressure | Age vs Sugar                |
------------------------------------------------
| Histogram      | Box Plot                    |
------------------------------------------------

# %%
Car Sales Dataset (10 Questions)

Q1. Display all cars whose Sales are greater than 100.

Q2. Display all cars whose Price is less than 12 lakh.

Q3. Display cars having Mileage greater than or equal to 19.

Q4. Display cars whose Sales are between 90 and 110.

Q5. Display cars whose Price is either 10 or 14 lakh.

Q6. Display cars whose Brand name starts with "T".

Q7. Display cars whose Brand name ends with "a".

Q8. Display cars whose Brand contains the letter "a".

Q9. Display cars having Sales greater than 90 and Mileage greater than 18.

Q10. Display cars having Price less than 11 or Mileage greater than 20.


Hospital Patient Dataset (10 Questions)

Q11. Display patients whose Age is greater than 40.

Q12. Display patients whose Blood Pressure is less than 140.

Q13. Display patients having Sugar level greater than 140.

Q14. Display patients whose Age is between 30 and 50.

Q15. Display patients whose Blood Pressure is either 120 or 160.

Q16. Display patients whose Patient ID starts with "P".

Q17. Display patients having Blood Pressure greater than 145 and Sugar greater than 150.

Q18. Display patients having Age less than 35 or Sugar greater than 160.

Q19. Display patients whose Age is not equal to 40.

Q20. Display patients whose Blood Pressure is between 130 and 155 and Sugar is greater than 100.
