# %%
#process to handle rumtime errors
try:
    n1 = int(input("Enter the first numbr"))
    n2 = int(input("Enter the first numbr"))
    d =n1/n2
except ZeroDivisionError as e:
    print("cant divide by zero")
except ValueError:
    print("Wrong value entered")
else:
    print("division = " ,d)
# Out:
# Enter the first numbr 6
# Enter the first numbr 0
# cant divide by zero

# %%
try:
    n1 = int(input("Enter the first number:"))
    n2 = int(input("Enter the first number:"))
    d =n1/n2
except Excception as e:
    print(e)
else:
    print(f"division= {d}")
finally:
    print("this block runs no matter what")
# Out:
# Enter the first numbr 5
# Enter the first numbr 6
# division= 0.8333333333333334
# this block runs no matter what
