# %%
while True:
    print("1. Addition")
    print("2. Subtraction")
    print("3. Multiplication")
    print("4. Division")
    print("5. Exit")

    choice = int(input("Enter your choise (1-5): "))

    if choice == 5:
        print("Calculator Closed.")
        break

    num1 = float(input("Enter first number: "))
    num2 = float(input("Enter second number: "))

    if choice == 1:
        print("Result =", num1 + num2)

    elif choice == 2:
        print("Result =", num1 - num2)

    elif choice == 3:
        print("Result =", num1 * num2)

    elif choice == 4:
        if num2 != 0:
            print("Result =", num1 / num2)
        else:
            print("Error! Division by zero is not allowed.")

    else:
        print("Invalid Choice! Please select between 1 and 5.")
# Out:
# ===== Calculator Menu =====
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Exit
# Enter your choice (1-5):  3
# Enter first number:  5
# Enter second number:  6
# Result = 30.0
#
# ===== Calculator Menu =====
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Exit
# Enter your choice (1-5):  2
# Enter first number:  2898654564564564564656
# Enter second number:  50145465
# Result = 2.8986545645645144e+21
#
# ===== Calculator Menu =====
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Exit
# Enter your choice (1-5):  2
# Enter first number:  33
# Enter second number:  33
# Result = 0.0
#
# ===== Calculator Menu =====
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Exit
# Enter your choice (1-5):  5
# Calculator Closed.

# %%
def filehandling(a,b,op,result):
    file =  open("history.txt", "a")
    file.write(f"{a} {op} {b} = {result}\n")
    file.close()
    print("data written successfully")
    
def addition(a, b):
    result = a + b
    filehandling(a,b,"+",result)
    return result


def subtraction(a, b):
    result = a - b
    filehandling(a,b,"-",result)
    return result


def multiplication(a, b):
    result = a * b
    filehandling(a,b,"*",result)
    return result


def division(a, b):
    if b == 0:
        return "Division by zero is not allowed!"

    result = a / b
    filehandling(a,b,"/",result)
    return result


while True:
    num1 = float(input("Enter first number: "))
    num2 = float(input("Enter second number: "))

    print("1. Addition")
    print("2. Subtraction")
    print("3. Multiplication")
    print("4. Division")
    

    choice = int(input("Enter your choice (1-4): "))

    if choice == 1:
        print("Result =", addition(num1, num2))
        

    elif choice == 2:
        print("Result =", subtraction(num1, num2))

    elif choice == 3:
        print("Result =", multiplication(num1, num2))

    elif choice == 4:
        print("Result =", division(num1, num2))

    else:
        print("Invalid Choice!")
# Out:
# ===== MENU =====
# 1. Factorial
# 2. Minimum
# 3. Maximum
# 4. Average
# 5. Even/Odd
# 6. Exit
# Enter your choice:  2
# Enter first number:  23
# Enter second number:  251
# Minimum = 23
#
# ===== MENU =====
# 1. Factorial
# 2. Minimum
# 3. Maximum
# 4. Average
# 5. Even/Odd
# 6. Exit
# Enter your choice:  5
# Enter a number:  55
# 55 is Odd
#
# ===== MENU =====
# 1. Factorial
# 2. Minimum
# 3. Maximum
# 4. Average
# 5. Even/Odd
# 6. Exit
# Enter your choice:  2
# Enter first number:  53
# Enter second number:  20
# Minimum = 20
#
# ===== MENU =====
# 1. Factorial
# 2. Minimum
# 3. Maximum
# 4. Average
# 5. Even/Odd
# 6. Exit
# Enter your choice:  4
# Enter first number:  2
# Enter second number:  2
# Average = 2.0
#
# ===== MENU =====
# 1. Factorial
# 2. Minimum
# 3. Maximum
# 4. Average
# 5. Even/Odd
# 6. Exit
# Enter your choice:  6
# Program Ended.

# %%
def filehandling(a,b,op,result):
    file =  open("history.txt", "a")
    file.write(f"{a} {op} {b} = {result}\n")
    file.close()
    print("data written successfully")
    
def addition(a, b):
    result = a + b
    filehandling(a,b,"+",result)
    return result


def subtraction(a, b):
    result = a - b
    filehandling(a,b,"-",result)
    return result


def multiplication(a, b):
    result = a * b
    filehandling(a,b,"*",result)
    return result


def division(a, b):
    if b == 0:
        return "Division by zero is not allowed!"

    result = a / b
    filehandling(a,b,"/",result)
    return result


while True:
    num1 = float(input("Enter first number: "))
    num2 = float(input("Enter second number: "))

    print("1. Addition")
    print("2. Subtraction")
    print("3. Multiplication")
    print("4. Division")
    

    choice = int(input("Enter your choice (1-4): "))

    if choice == 1:
        print("Result =", addition(num1, num2))
        

    elif choice == 2:
        print("Result =", subtraction(num1, num2))

    elif choice == 3:
        print("Result =", multiplication(num1, num2))

    elif choice == 4:
        print("Result =", division(num1, num2))

    else:
        print("Invalid Choice!")
# Out:
# Enter first number:  5
# Enter second number:  6
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# Enter your choice (1-4):  1
# data written successfully
# Result = 11.0
# Enter first number:  6
# Enter second number:  3
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# Enter your choice (1-4):  3
# data written successfully
# Result = 18.0

# %%
def filehandling(op, result):
    file = open("functiond.txt", a)
    file.write(f"{op} = {result}\n")
    file.close()
    print(data entered successfully)


def fact(n):
    if n <= 1:
        return 1
    return n * fact(n - 1)
    filehandling(f"Factorial of {n}",result)


def min_num(n1, n2):
    if n1 > n2:
        return n2
    return n1

def max_num(n1, n2):
    if n1 > n2:
        return n1
    return n2


def average(n1, n2):
    return (n1 + n2) / 2


def even_odd(n):
    if n % 2 == 0:
        return "Even"
    return "Odd"


while True:
    
    print("1. Factorial")
    print("2. Minimum")
    print("3. Maximum")
    print("4. Average")
    print("5. Even/Odd")
    print("6. Exit")

    choice = int(input("Enter your choice: "))

    if choice == 1:
        n = int(input("Enter a number: "))
        print("Factorial =", fact(n))

    elif choice == 2:
        n1 = int(input("Enter first number: "))
        n2 = int(input("Enter second number: "))
        print("Minimum =", min_num(n1, n2))

    elif choice == 3:
        n1 = int(input("Enter first number: "))
        n2 = int(input("Enter second number: "))
        print("Maximum =", max_num(n1, n2))

    elif choice == 4:
        n1 = int(input("Enter first number: "))
        n2 = int(input("Enter second number: "))
        print("Average =", average(n1, n2))

    elif choice == 5:
        n = int(input("Enter a number: "))
        print(n, "is", even_odd(n))

    elif choice == 6:
        print("Program Ended.")
        break

    else:
        print("Invalid Choice!")
